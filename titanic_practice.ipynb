# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2 = df.drop(columns='Cabin')

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df2.dropna(subset=['Embarked'],inplace=True)

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  712.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.642093    0.524184
# std     256.998173    0.486260    0.834700   14.492933    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.000000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df2['Age'].fillna(df2['Age'].mean(),inplace=True)

# %%
df2['Age'].round(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    30.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 889, dtype: float64

# %%
df2['Age'] = df2['Age'].astype(int)

# %%
df2.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   29      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df2[(df2.Age <= 0)]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#      Age  SibSp  Parch  Ticket      Fare Embarked
# 78     0      0      2  248738   29.0000        S
# 305    0      1      2  113781  151.5500        S
# 469    0      2      1    2666   19.2583        C
# 644    0      2      1    2666   19.2583        C
# 755    0      1      1  250649   14.5000        S
# 803    0      0      1    2625    8.5167        C
# ...

# %%
df2.drop(index=[78,305,469,644,755,803,831],inplace=True)

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   882.000000  882.000000  882.000000  882.000000  882.000000
# mean    445.126984    0.377551    2.311791   29.732426    0.520408
# std     256.763846    0.485049    0.835681   12.760914    1.105210
# min       1.000000    0.000000    1.000000    1.000000    0.000000
# 25%     223.250000    0.000000    2.000000   22.000000    0.000000
# 50%     444.500000    0.000000    3.000000   29.000000    0.000000
# 75%     666.750000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  882.000000  882.000000
# mean     0.375283   32.055687
# std      0.804909   49.716175
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df2.shape
# Out:
# (882, 11)

# %%
X = df2[['Pclass', 'Age','SibSp','Parch','Fare']]
X
# Out:
#      Pclass  Age  SibSp  Parch     Fare
# 0         3   22      1      0   7.2500
# 1         1   38      1      0  71.2833
# 2         3   26      0      0   7.9250
# 3         1   35      1      0  53.1000
# 4         3   35      0      0   8.0500
# ..      ...  ...    ...    ...      ...
# 886       2   27      0      0  13.0000
# 887       1   19      0      0  30.0000
# 888       3   29      1      2  23.4500
# 889       1   26      0      0  30.0000
# 890       3   32      0      0   7.7500
#
# [882 rows x 5 columns]

# %%
Y = df2['Survived']
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 882, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (617, 5)
# (265, 5)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = lr.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7396226415094339

# %%
for i in df2.Sex:
    i = i.lower()

# %%
df2['Sex_male'] = df2['Sex'].copy()
df2['Sex_female'] = df2['Sex'].copy()

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked Sex_male Sex_female
# 0      0         A/5 21171   7.2500        S     male       male
# 1      0          PC 17599  71.2833        C   female     female
# 2      0  STON/O2. 3101282   7.9250        S   female     female
# ...

# %%
gender = {'male':1,'female':0}
df2.Sex_male = [gender[item] for item in df2.Sex_male]
gender2 = {'male':0,'female':1}
df2.Sex_female = [gender2[item] for item in df2.Sex_female]

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked  Sex_male  Sex_female
# 0      0         A/5 21171   7.2500        S         1           0
# 1      0          PC 17599  71.2833        C         0           1
# 2      0  STON/O2. 3101282   7.9250        S         0           1
# ...

# %%
x1 = df2[['Pclass', 'Age','SibSp','Parch','Fare','Sex_male','Sex_female']]
x1
# Out:
#      Pclass  Age  SibSp  Parch     Fare  Sex_male  Sex_female
# 0         3   22      1      0   7.2500         1           0
# 1         1   38      1      0  71.2833         0           1
# 2         3   26      0      0   7.9250         0           1
# 3         1   35      1      0  53.1000         0           1
# 4         3   35      0      0   8.0500         1           0
# ..      ...  ...    ...    ...      ...       ...         ...
# 886       2   27      0      0  13.0000         1           0
# 887       1   19      0      0  30.0000         0           1
# 888       3   29      1      2  23.4500         0           1
# 889       1   26      0      0  30.0000         1           0
# 890       3   32      0      0   7.7500         1           0
#
# [882 rows x 7 columns]

# %%
y1 = df2[['Survived']]
y1
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [882 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=0.3, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (617, 7)
# (265, 7)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\tncba\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\tncba\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
# ...

# %%
#add sex to model
y_pred = lr.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8188679245283019

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test, y_pred)
cf
# Out:
# array([[151,  16],
#        [ 32,  66]], dtype=int64)

# %%
import seaborn as sns
sns.heatmap(cf, annot=True)

# %%
from sklearn.metrics import precision_score , recall_score, f1_score
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86       167
#            1       0.80      0.67      0.73        98
#
#     accuracy                           0.82       265
#    macro avg       0.82      0.79      0.80       265
# weighted avg       0.82      0.82      0.81       265

# %%
df2.Embarked.count()
# Out:
# 882

# %%
df2['Age_square'] = df2['Age'].apply(lambda x:x**2)

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked  Sex_male  Sex_female  Age_square
# 0      0         A/5 21171   7.2500        S         1           0         484
# 1      0          PC 17599  71.2833        C         0           1        1444
# 2      0  STON/O2. 3101282   7.9250        S         0           1         676
# ...

# %%
df2['Fare_round'] = df2['Fare'].round(0)

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked  Sex_male  Sex_female  \
# 0      0         A/5 21171   7.2500        S         1           0
# 1      0          PC 17599  71.2833        C         0           1
# 2      0  STON/O2. 3101282   7.9250        S         0           1
# ...

# %%
df2.drop(columns='Ticket',inplace=True)

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch     Fare Embarked  Sex_male  Sex_female  Age_square  Fare_round
# 0      0   7.2500        S         1           0         484         7.0
# 1      0  71.2833        C         0           1        1444        71.0
# 2      0   7.9250        S         0           1         676         8.0
# ...

# %%
df2['Cherbourg']= df2['Embarked'].copy()
df2['Queenstown']= df2['Embarked'].copy()
df2['Southampton'] = df2['Embarked'].copy()

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch     Fare Embarked  Sex_male  Sex_female  Age_square  Fare_round  \
# 0      0   7.2500        S         1           0         484         7.0
# 1      0  71.2833        C         0           1        1444        71.0
# 2      0   7.9250        S         0           1         676         8.0
# ...

# %%
Embark = {'S':1,'Q':0,'C':0}
df2.Southampton = [Embark[item] for item in df2.Southampton]
Embark2 = {'S':0,'Q':1,'C':0}
df2.Queenstown = [Embark2[item] for item in df2.Queenstown]
Embark3 = {'S':0,'Q':0,'C':1}
df2.Cherbourg = [Embark3[item] for item in df2.Cherbourg]

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch     Fare Embarked  Sex_male  Sex_female  Age_square  Fare_round  \
# 0      0   7.2500        S         1           0         484         7.0
# 1      0  71.2833        C         0           1        1444        71.0
# 2      0   7.9250        S         0           1         676         8.0
# ...

# %%
df2.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.009454 -0.038145  0.039579 -0.060523 -0.001532
# Survived       -0.009454  1.000000 -0.338345 -0.051145 -0.038739  0.072772
# Pclass         -0.038145 -0.338345  1.000000 -0.340224  0.080974  0.019907
# Age             0.039579 -0.051145 -0.340224  1.000000 -0.229549 -0.159843
# SibSp          -0.060523 -0.038739  0.080974 -0.229549  1.000000  0.415633
# Parch          -0.001532  0.072772  0.019907 -0.159843  0.415633  1.000000
# Fare            0.016143  0.256805 -0.546776  0.095066  0.161505  0.215741
# Sex_male        0.043063 -0.548455  0.132656  0.092552 -0.113244 -0.252877
# Sex_female     -0.043063  0.548455 -0.132656 -0.092552  0.113244  0.252877
# Age_square      0.029726 -0.033141 -0.347122  0.952446 -0.157567 -0.080064
# Fare_round      0.016132  0.256588 -0.546915  0.095211  0.161791  0.215471
# ...

# %%
x2 = df2[['Pclass', 'Age','SibSp','Parch','Fare','Sex_male','Sex_female','Cherbourg','Queenstown','Southampton']]
x2
# Out:
#      Pclass  Age  SibSp  Parch     Fare  Sex_male  Sex_female  Cherbourg  \
# 0         3   22      1      0   7.2500         1           0          0
# 1         1   38      1      0  71.2833         0           1          1
# 2         3   26      0      0   7.9250         0           1          0
# 3         1   35      1      0  53.1000         0           1          0
# 4         3   35      0      0   8.0500         1           0          0
# ..      ...  ...    ...    ...      ...       ...         ...        ...
# 886       2   27      0      0  13.0000         1           0          0
# 887       1   19      0      0  30.0000         0           1          0
# 888       3   29      1      2  23.4500         0           1          0
# 889       1   26      0      0  30.0000         1           0          1
# 890       3   32      0      0   7.7500         1           0          0
#
#      Queenstown  Southampton
# 0             0            1
# 1             0            0
# ...

# %%
y2 = df2[['Survived']]
y2
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [882 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x2, y2, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\tncba\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\tncba\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
# ...

# %%
#add sex to model
y_pred = lr.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8188679245283019

# %%
#test

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_test.drop(columns='Cabin',inplace=True)

# %%
df_test['Fare'].fillna(df_test['Fare'].mean(),inplace= True)

# %%
df_test['Age'].fillna(df_test['Age'].mean(),inplace= True)

# %%
df_test[(df_test.Age < 1)]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 250         1142       2                    West, Miss. Barbara J  female
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
#
#       Age  SibSp  Parch              Ticket    Fare Embarked
# 201  0.33      0      2              347080  14.400        S
# 250  0.92      1      2          C.A. 34651  27.750        S
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.775        S
# 307  0.83      0      1              392091   9.350        S
# 354  0.17      1      2           C.A. 2315  20.575        S

# %%
df_test['Age'].iloc[[201,250,281,307,354]] = df.Age.mean()

# %%
df_test[(df_test.Age <= 0)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
df_test['Age'].round(0)
# Out:
# 0      34.0
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413    30.0
# 414    39.0
# 415    38.0
# 416    30.0
# 417    30.0
# Name: Age, Length: 418, dtype: float64

# %%
df_test['Age'] = df_test['Age'].astype(int)

# %%
df_test.shape
# Out:
# (418, 10)

# %%
df_test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df_test['Sex_male'] = df_test['Sex'].copy()
df_test['Sex_female'] = df_test['Sex'].copy()

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#    Age  SibSp  Parch   Ticket     Fare Embarked Sex_male Sex_female
# 0   34      0      0   330911   7.8292        Q     male       male
# 1   47      1      0   363272   7.0000        S   female     female
# 2   62      0      0   240276   9.6875        Q     male       male
# 3   27      0      0   315154   8.6625        S     male       male
# 4   22      1      1  3101298  12.2875        S   female     female

# %%
gender = {'male':1,'female':0}
df_test.Sex_male = [gender[item] for item in df_test.Sex_male]
gender2 = {'male':0,'female':1}
df_test.Sex_female = [gender2[item] for item in df_test.Sex_female]

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#    Age  SibSp  Parch   Ticket     Fare Embarked  Sex_male  Sex_female
# 0   34      0      0   330911   7.8292        Q         1           0
# 1   47      1      0   363272   7.0000        S         0           1
# 2   62      0      0   240276   9.6875        Q         1           0
# 3   27      0      0   315154   8.6625        S         1           0
# 4   22      1      1  3101298  12.2875        S         0           1

# %%
df_test['Cherbourg']= df_test['Embarked'].copy()
df_test['Queenstown']= df_test['Embarked'].copy()
df_test['Southampton'] = df_test['Embarked'].copy()

# %%
Embark = {'S':1,'Q':0,'C':0}
df_test.Southampton = [Embark[item] for item in df_test.Southampton]
Embark2 = {'S':0,'Q':1,'C':0}
df_test.Queenstown = [Embark2[item] for item in df_test.Queenstown]
Embark3 = {'S':0,'Q':0,'C':1}
df_test.Cherbourg = [Embark3[item] for item in df_test.Cherbourg]

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#    Age  SibSp  Parch   Ticket     Fare Embarked  Sex_male  Sex_female  \
# 0   34      0      0   330911   7.8292        Q         1           0
# 1   47      1      0   363272   7.0000        S         0           1
# 2   62      0      0   240276   9.6875        Q         1           0
# 3   27      0      0   315154   8.6625        S         1           0
# 4   22      1      1  3101298  12.2875        S         0           1
#
#    Cherbourg  Queenstown  Southampton
# 0          0           1            0
# ...

# %%
xt = df_test[['Pclass', 'Age','SibSp','Parch','Fare','Sex_male','Sex_female','Cherbourg','Queenstown','Southampton']]
xt
# Out:
#      Pclass  Age  SibSp  Parch      Fare  Sex_male  Sex_female  Cherbourg  \
# 0         3   34      0      0    7.8292         1           0          0
# 1         3   47      1      0    7.0000         0           1          0
# 2         2   62      0      0    9.6875         1           0          0
# 3         3   27      0      0    8.6625         1           0          0
# 4         3   22      1      1   12.2875         0           1          0
# ..      ...  ...    ...    ...       ...       ...         ...        ...
# 413       3   30      0      0    8.0500         1           0          0
# 414       1   39      0      0  108.9000         0           1          1
# 415       3   38      0      0    7.2500         1           0          0
# 416       3   30      0      0    8.0500         1           0          0
# 417       3   30      1      1   22.3583         1           0          1
#
#      Queenstown  Southampton
# 0             1            0
# ...

# %%
y_pred_test = lr.predict(xt)
y_pred_test = pd.DataFrame(y_pred_test, columns=['Prediction'])
y_pred_test.iloc[381:]
# Out:
#      Prediction
# 381           0
# 382           1
# 383           1
# 384           0
# 385           1
# 386           0
# 387           0
# 388           0
# 389           0
# 390           1
# 391           1
# 392           0
# 393           0
# 394           0
# 395           1
# 396           0
# 397           1
# 398           0
# 399           0
# 400           1
# 401           0
# 402           1
# 403           1
# 404           0
# 405           0
# 406           0
# 407           0
# 408           1
# 409           1
# 410           1
# 411           1
# 412           1
# 413           0
# 414           1
# 415           0
# 416           0
# 417           0

# %%
compare_table = df_test[''].join(y_pred_test)
compare_table

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 
 'n_estimators': [100,200,300,400,500,600],
 'max_features': ['auto', 'sqrt', 'log2'],
 'max_depth' : [2,3,4,5,6,7,8,9,10],
 'criterion' :['gini', 'entropy']
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(x_train, y_train)
# Out:
# C:\Users\tncba\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\tncba\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\tncba\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'max_features': 'auto',
#  'n_estimators': 100}

# %%
rfc1=RandomForestClassifier(random_state=42, max_features='auto', n_estimators= 300, max_depth=10, criterion='entropy')
rfc1.fit(x_train, y_train)
# Out:
# C:\Users\tncba\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
pred=rfc1.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.8226415094339623
